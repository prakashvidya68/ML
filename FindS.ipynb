# %%
h=['phi','phi','phi','phi','phi','phi']


Data=[['Sunny','Warm','Normal','Strong','Warm','Same','Yes'], 

      ['Sunny','Warm','High','Strong','Warm','Same','Yes'], 

      ['Sunny','Warm','Normal','Strong','Warm','Same','No'], 

      ['Sunny','Warm','High','Strong','Cool','Change','Yes'] 

     ] 


def isConsistent(h,d): 
    if len(h)!=len(d)-1: 

        print('Number of attributes are not same in hypothesis.') 

        return False 

    else:

        matched=0

        for i in range(len(h)): 

            if ( (h[i]==d[i]) or (h[i]=='any') ): 

                matched=matched+1 

        if matched==len(h): 

            return True 

        else: 

            return False 
        
        
def makeConsistent(h,d): 
    for i in range(len(h)):         

        if((h[i] == 'phi')): 

            h[i]=d[i] 

            

        elif(h[i]!=d[i]): 

            h[i]='any'

    return h 


print('Begin : Hypothesis:{}'.format(h)) 

print('==========================================') 



for d in Data: 

    if d[len(d)-1]=='Yes': 

        if ( isConsistent(h,d)): 

            print ("Hypothesis :",d) 

        else: 
            h=makeConsistent(h,d) 

        print ('Training data         :',d) 

        print ('Updated Hypothesis    :',h) 

        print() 

        print('--------------------------------') 

print('==========================================') 

print('End: Hypothesis :',h)
# Out:
# Begin : Hypothesis:['phi', 'phi', 'phi', 'phi', 'phi', 'phi']
# ==========================================
# Training data         : ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same', 'Yes']
# Updated Hypothesis    : ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same']
#
# --------------------------------
# Training data         : ['Sunny', 'Warm', 'High', 'Strong', 'Warm', 'Same', 'Yes']
# Updated Hypothesis    : ['Sunny', 'Warm', 'any', 'Strong', 'Warm', 'Same']
#
# --------------------------------
# Training data         : ['Sunny', 'Warm', 'High', 'Strong', 'Cool', 'Change', 'Yes']
# Updated Hypothesis    : ['Sunny', 'Warm', 'any', 'Strong', 'any', 'any']
#
# --------------------------------
# ==========================================
# End: Hypothesis : ['Sunny', 'Warm', 'any', 'Strong', 'any', 'any']

# %%
h=['phi','phi','phi','phi','phi','phi']


Data=[['Sunny','Warm','Normal','Strong','Warm','Same','Yes'], 

      ['Sunny','Warm','High','Strong','Warm','Same','Yes'], 

      ['Sunny','Warm','Normal','Strong','Warm','Same','No'], 

      ['Sunny','Warm','High','Strong','Cool','Change','Yes'] 

     ] 


def isConsistant(h,d):
    matched = 0
    if len(h) != len(d) - 1:
        print('Number of attributes are not same in hypothesis.') 
        return False
    for i in range(len(d) - 1):
        if (d[i] == h[i] or d[i] == "any"):
            matched += 1
        
    
    if(matched == len(h)):
        return True
    
    else:
        return False
    
    
def makeConsistant(h,d):
    for i in range(len(d) - 1):
        if(h[i] == "phi"):
            h[i] = d[i]
        
        elif(d[i] != h[i] and h[i] != "any"):
            h[i] = "any"
            
    return h



print("BEGIN: Hypothesis: {}".format(h))
print("========================================\n")

for d in Data:
    if(d[len(d) - 1] == "Yes"):
        if(isConsistant(h,d)):
            print("Hypothesis: {}\n".format(d))
    
        else:
            h = makeConsistant(h,d)

        print("Training Data : {}\n".format(d))

        print("Updated Hypothesis: {}\n".format(h))

        print("__________________________________________\n")
    

print("========================================\n")
    
print("Final Hypothesis: {}".format(h))
# Out:
# BEGIN: Hypothesis: ['phi', 'phi', 'phi', 'phi', 'phi', 'phi']
# ========================================
#
# Training Data : ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same', 'Yes']
#
# Updated Hypothesis: ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same']
#
# __________________________________________
#
# Training Data : ['Sunny', 'Warm', 'High', 'Strong', 'Warm', 'Same', 'Yes']
#
# Updated Hypothesis: ['Sunny', 'Warm', 'any', 'Strong', 'Warm', 'Same']
#
# __________________________________________
#
# Training Data : ['Sunny', 'Warm', 'High', 'Strong', 'Cool', 'Change', 'Yes']
#
# Updated Hypothesis: ['Sunny', 'Warm', 'any', 'Strong', 'any', 'any']
#
# __________________________________________
#
# ========================================
#
# Final Hypothesis: ['Sunny', 'Warm', 'any', 'Strong', 'any', 'any']
